# %%
import pandas as pd

df = pd.read_excel('Scan File.xls')
df
# Out:
#    Barcode Number   Source   Room Federal?                   Description  \
# 0           11944   TipWeb    223      YES           ASUS CHROMEBOX CN60
# 1            8010   TipWeb  LOBBY      NaN  CRES COR C0151FPWUA12B2083Q1
# 2            2330  NextGen   CAFE      NaN                 CUP DISPENSER
# 3            3715  NextGen    602      NaN                COMPUTER TOWER
# 4           11762      NaN    107      YES                        Laptop
# 5           12667      NaN    208      NaN                    Smartboard
#
#   Manufacturer         Model Number      Serial Number        Cost Center  \
# 0         ASUS       CHROMEBOX CN60       E4MSCX011443   High School West
# 1     CRES COR  C0151FPWUA12B2083Q1    EAJ-J203747-044   High School West
# 2       HOBART             CTC2X2-5                NaN  Elementary School
# 3           HP                 360X  00045-571-601-835  Elementary School
# 4       lenovo                 100e          CD5294G9T      Middle School
# ...

# %%
test = df.loc[:, 'Source']
test
# Out:
# 0     TipWeb
# 1     TipWeb
# 2    NextGen
# 3    NextGen
# 4        NaN
# 5        NaN
# Name: Source, dtype: object
