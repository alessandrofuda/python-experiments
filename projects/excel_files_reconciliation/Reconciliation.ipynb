# %%
import numpy as np
import pandas as pd

# %%
def figure_out_status(x):
    # No barcode in scan file -> Status = "M"
    reference_barcode = x['Barcode Number_reference']
    scan_barcode = x['Barcode Number_scan']

    if reference_barcode is not None and scan_barcode is None:
        return 'M'

    # No barcode in reference file -> Status = "N"
    if scan_barcode is not None and reference_barcode is None:
        return 'N'

    # Change found in reference file -> Status = "C"
    reference = [col for col in x.index if col.endswith('_reference')]
    scan = [col for col in x.index if col.endswith('_scan')]
    reference_data = {col.replace('_reference', ''): x[col] for col in reference}
    scan_data = {col.replace('_scan', ''): x[col] for col in scan}

    for key in reference_data:
        if reference_data[key] != scan_data[key]:
            return 'C'

    # No changes found in reference file -> Status = "F"
    return 'F'

# %%
# Converting columns to a specific type helps with comparison
converters = {
    'Barcode Number': str,
    'Source': str,
    'Room': str,
    'Federal?': str,
    'Description': str,
    'Manufacturer': str,
    'Model Number': str,
    'Serial Number': str,
    'Cost Center': str,
    'COST': int,
    'Date Acquired': str,
    'Funding Code': str,
    'PO Number': str,
}

df = pd.read_excel('Scan File.xls', converters=converters)
df.insert(0, 'key', df.loc[:, 'Barcode Number'])
df
# Out:
#      key Barcode Number   Source   Room Federal?  \
# 0  11944          11944   TipWeb    223      YES
# 1   8010           8010   TipWeb  LOBBY      NaN
# 2   2330           2330  NextGen   CAFE      NaN
# 3   3715           3715  NextGen    602      NaN
# 4  11762          11762      NaN    107      YES
# 5  12667          12667      NaN    208      NaN
#
#                     Description Manufacturer         Model Number  \
# 0           ASUS CHROMEBOX CN60         ASUS       CHROMEBOX CN60
# 1  CRES COR C0151FPWUA12B2083Q1     CRES COR  C0151FPWUA12B2083Q1
# 2                 CUP DISPENSER       HOBART             CTC2X2-5
# 3                COMPUTER TOWER           HP                 360X
# 4                        Laptop       lenovo                 100e
# 5                    Smartboard    Viewsonic             VS 15057
#
#        Serial Number        Cost Center  COST Date Acquired Funding Code  \
# 0       E4MSCX011443   High School West  1100           NaN         6001
# 1    EAJ-J203747-044   High School West  1458    2009-08-01         5101
# 2                NaN  Elementary School   385    2004-07-23         5101
# 3  00045-571-601-835  Elementary School   693    2011-02-22            0
# 4          CD5294G9T      Middle School   NaN           NaN          NaN
# 5        VS812847203  Elementary School   NaN           NaN          NaN
#
#   PO Number
# 0   23-5432
# 1   FF-2234
# 2    510307
# 3       NaN
# 4       NaN
# 5       NaN

# %%
df2 = pd.read_excel('Reference File.xls', converters=converters)
df2.insert(0, 'key', df2.loc[:, 'Barcode Number'])
df2
# Out:
#      key Barcode Number   Source     Room Federal?  \
# 0  11944          11944   TipWeb      223      YES
# 1  11965          11965   TipWeb      210      YES
# 2   8010           8010   TipWeb  KITCHEN      NaN
# 3   2330           2330  NextGen     CAFE      NaN
# 4   3715           3715  NextGen      602      NaN
#
#                     Description Manufacturer         Model Number  \
# 0           ASUS CHROMEBOX CN60         ASUS       CHROMEBOX CN60
# 1           ASUS CHROMEBOX CN60         ASUS       CHROMEBOX CN60
# 2  CRES COR C0151FPWUA12B2083Q1     CRES COR  C0151FPWUA12B2083Q1
# 3                 CUP DISPENSER       HOBART             CTC2X2-5
# 4                COMPUTER TOWER         DELL         OPTIPLEX 280
#
#        Serial Number        Cost Center  COST Date Acquired Funding Code  \
# 0       E4MSCX011443   High School West  1100           NaN         6001
# 1       E4MSCX012824   High School East  2300           NaN         6001
# 2    EAJ-J203747-044      Middle School  1458    2009-08-01         5101
# 3                NaN  Elementary School   385    2004-07-23         5101
# 4  00045-571-601-835  Elementary School   693    2011-02-22            0
#
#   PO Number
# 0       NaN
# 1   24-1234
# 2   FF-2234
# 3    510307
# 4       NaN

# %%
diffs_df = pd.merge(df, df2, suffixes=('_scan', '_reference'), how="outer", on=["key"])
diffs_df
# Out:
#      key Barcode Number_scan Source_scan Room_scan Federal?_scan  \
# 0  11944               11944      TipWeb       223           YES
# 1   8010                8010      TipWeb     LOBBY           NaN
# 2   2330                2330     NextGen      CAFE           NaN
# 3   3715                3715     NextGen       602           NaN
# 4  11762               11762         NaN       107           YES
# 5  12667               12667         NaN       208           NaN
# 6  11965                 NaN         NaN       NaN           NaN
#
#                Description_scan Manufacturer_scan    Model Number_scan  \
# 0           ASUS CHROMEBOX CN60              ASUS       CHROMEBOX CN60
# 1  CRES COR C0151FPWUA12B2083Q1          CRES COR  C0151FPWUA12B2083Q1
# 2                 CUP DISPENSER            HOBART             CTC2X2-5
# 3                COMPUTER TOWER                HP                 360X
# 4                        Laptop            lenovo                 100e
# 5                    Smartboard         Viewsonic             VS 15057
# 6                           NaN               NaN                  NaN
#
#   Serial Number_scan   Cost Center_scan  ... Federal?_reference  \
# 0       E4MSCX011443   High School West  ...                YES
# 1    EAJ-J203747-044   High School West  ...                NaN
# 2                NaN  Elementary School  ...                NaN
# 3  00045-571-601-835  Elementary School  ...                NaN
# 4          CD5294G9T      Middle School  ...                NaN
# 5        VS812847203  Elementary School  ...                NaN
# 6                NaN                NaN  ...                YES
#
#           Description_reference Manufacturer_reference Model Number_reference  \
# 0           ASUS CHROMEBOX CN60                   ASUS         CHROMEBOX CN60
# 1  CRES COR C0151FPWUA12B2083Q1               CRES COR    C0151FPWUA12B2083Q1
# 2                 CUP DISPENSER                 HOBART               CTC2X2-5
# 3                COMPUTER TOWER                   DELL           OPTIPLEX 280
# 4                           NaN                    NaN                    NaN
# 5                           NaN                    NaN                    NaN
# 6           ASUS CHROMEBOX CN60                   ASUS         CHROMEBOX CN60
#
#   Serial Number_reference Cost Center_reference COST_reference  \
# 0            E4MSCX011443      High School West         1100.0
# 1         EAJ-J203747-044         Middle School         1458.0
# 2                     NaN     Elementary School          385.0
# 3       00045-571-601-835     Elementary School          693.0
# 4                     NaN                   NaN            NaN
# 5                     NaN                   NaN            NaN
# 6            E4MSCX012824      High School East         2300.0
#
#   Date Acquired_reference Funding Code_reference PO Number_reference
# 0                     NaN                   6001                 NaN
# 1              2009-08-01                   5101             FF-2234
# 2              2004-07-23                   5101              510307
# 3              2011-02-22                      0                 NaN
# 4                     NaN                    NaN                 NaN
# 5                     NaN                    NaN                 NaN
# 6                     NaN                   6001             24-1234
#
# [7 rows x 27 columns]

# %%
# Fix `NaN` values to be `None` so we can compare them
diffs_df = diffs_df.replace({np.nan: None})
diffs_df
# Out:
#      key Barcode Number_scan Source_scan Room_scan Federal?_scan  \
# 0  11944               11944      TipWeb       223           YES
# 1   8010                8010      TipWeb     LOBBY          None
# 2   2330                2330     NextGen      CAFE          None
# 3   3715                3715     NextGen       602          None
# 4  11762               11762        None       107           YES
# 5  12667               12667        None       208          None
# 6  11965                None        None      None          None
#
#                Description_scan Manufacturer_scan    Model Number_scan  \
# 0           ASUS CHROMEBOX CN60              ASUS       CHROMEBOX CN60
# 1  CRES COR C0151FPWUA12B2083Q1          CRES COR  C0151FPWUA12B2083Q1
# 2                 CUP DISPENSER            HOBART             CTC2X2-5
# 3                COMPUTER TOWER                HP                 360X
# 4                        Laptop            lenovo                 100e
# 5                    Smartboard         Viewsonic             VS 15057
# 6                          None              None                 None
#
#   Serial Number_scan   Cost Center_scan  ... Federal?_reference  \
# 0       E4MSCX011443   High School West  ...                YES
# 1    EAJ-J203747-044   High School West  ...               None
# 2               None  Elementary School  ...               None
# 3  00045-571-601-835  Elementary School  ...               None
# 4          CD5294G9T      Middle School  ...               None
# 5        VS812847203  Elementary School  ...               None
# 6               None               None  ...                YES
#
#           Description_reference Manufacturer_reference Model Number_reference  \
# 0           ASUS CHROMEBOX CN60                   ASUS         CHROMEBOX CN60
# 1  CRES COR C0151FPWUA12B2083Q1               CRES COR    C0151FPWUA12B2083Q1
# 2                 CUP DISPENSER                 HOBART               CTC2X2-5
# 3                COMPUTER TOWER                   DELL           OPTIPLEX 280
# 4                          None                   None                   None
# 5                          None                   None                   None
# 6           ASUS CHROMEBOX CN60                   ASUS         CHROMEBOX CN60
#
#   Serial Number_reference Cost Center_reference COST_reference  \
# 0            E4MSCX011443      High School West         1100.0
# 1         EAJ-J203747-044         Middle School         1458.0
# 2                    None     Elementary School          385.0
# 3       00045-571-601-835     Elementary School          693.0
# 4                    None                  None           None
# 5                    None                  None           None
# 6            E4MSCX012824      High School East         2300.0
#
#   Date Acquired_reference Funding Code_reference PO Number_reference
# 0                    None                   6001                None
# 1              2009-08-01                   5101             FF-2234
# 2              2004-07-23                   5101              510307
# 3              2011-02-22                      0                None
# 4                    None                   None                None
# 5                    None                   None                None
# 6                    None                   6001             24-1234
#
# [7 rows x 27 columns]

# %%
# Add a new column to show the status of the row
diffs_df.insert(0, 'Status', value=diffs_df.apply(figure_out_status, axis=1))
diffs_df
# Out:
#   Status    key Barcode Number_scan Source_scan Room_scan Federal?_scan  \
# 0      C  11944               11944      TipWeb       223           YES
# 1      C   8010                8010      TipWeb     LOBBY          None
# 2      F   2330                2330     NextGen      CAFE          None
# 3      C   3715                3715     NextGen       602          None
# 4      N  11762               11762        None       107           YES
# 5      N  12667               12667        None       208          None
# 6      M  11965                None        None      None          None
#
#                Description_scan Manufacturer_scan    Model Number_scan  \
# 0           ASUS CHROMEBOX CN60              ASUS       CHROMEBOX CN60
# 1  CRES COR C0151FPWUA12B2083Q1          CRES COR  C0151FPWUA12B2083Q1
# 2                 CUP DISPENSER            HOBART             CTC2X2-5
# 3                COMPUTER TOWER                HP                 360X
# 4                        Laptop            lenovo                 100e
# 5                    Smartboard         Viewsonic             VS 15057
# 6                          None              None                 None
#
#   Serial Number_scan  ... Federal?_reference         Description_reference  \
# 0       E4MSCX011443  ...                YES           ASUS CHROMEBOX CN60
# 1    EAJ-J203747-044  ...               None  CRES COR C0151FPWUA12B2083Q1
# 2               None  ...               None                 CUP DISPENSER
# 3  00045-571-601-835  ...               None                COMPUTER TOWER
# 4          CD5294G9T  ...               None                          None
# 5        VS812847203  ...               None                          None
# 6               None  ...                YES           ASUS CHROMEBOX CN60
#
#   Manufacturer_reference Model Number_reference Serial Number_reference  \
# 0                   ASUS         CHROMEBOX CN60            E4MSCX011443
# 1               CRES COR    C0151FPWUA12B2083Q1         EAJ-J203747-044
# 2                 HOBART               CTC2X2-5                    None
# 3                   DELL           OPTIPLEX 280       00045-571-601-835
# 4                   None                   None                    None
# 5                   None                   None                    None
# 6                   ASUS         CHROMEBOX CN60            E4MSCX012824
#
#   Cost Center_reference COST_reference Date Acquired_reference  \
# 0      High School West         1100.0                    None
# 1         Middle School         1458.0              2009-08-01
# 2     Elementary School          385.0              2004-07-23
# 3     Elementary School          693.0              2011-02-22
# 4                  None           None                    None
# 5                  None           None                    None
# 6      High School East         2300.0                    None
#
#   Funding Code_reference PO Number_reference
# 0                   6001                None
# 1                   5101             FF-2234
# 2                   5101              510307
# 3                      0                None
# 4                   None                None
# 5                   None                None
# 6                   6001             24-1234
#
# [7 rows x 28 columns]

# %%
# We need to look at the status:
# For N - The row was added to the scan file, so we do nothing
# For M - The row is missing in scan file data, so we need to add it from the reference file
# For C - The row was changed in the scan file, so we just use that data, no actions needed
for column in diffs_df.columns:
    reference_column = column.replace('_scan', '_reference')
    diffs_df[column] = diffs_df.apply(lambda x: x[reference_column] if x['Status'] == 'M' else x[column], axis=1)
diffs_df
# Out:
#   Status    key Barcode Number_scan Source_scan Room_scan Federal?_scan  \
# 0      C  11944               11944      TipWeb       223           YES
# 1      C   8010                8010      TipWeb     LOBBY          None
# 2      F   2330                2330     NextGen      CAFE          None
# 3      C   3715                3715     NextGen       602          None
# 4      N  11762               11762        None       107           YES
# 5      N  12667               12667        None       208          None
# 6      M  11965               11965      TipWeb       210           YES
#
#                Description_scan Manufacturer_scan    Model Number_scan  \
# 0           ASUS CHROMEBOX CN60              ASUS       CHROMEBOX CN60
# 1  CRES COR C0151FPWUA12B2083Q1          CRES COR  C0151FPWUA12B2083Q1
# 2                 CUP DISPENSER            HOBART             CTC2X2-5
# 3                COMPUTER TOWER                HP                 360X
# 4                        Laptop            lenovo                 100e
# 5                    Smartboard         Viewsonic             VS 15057
# 6           ASUS CHROMEBOX CN60              ASUS       CHROMEBOX CN60
#
#   Serial Number_scan  ... Federal?_reference         Description_reference  \
# 0       E4MSCX011443  ...                YES           ASUS CHROMEBOX CN60
# 1    EAJ-J203747-044  ...               None  CRES COR C0151FPWUA12B2083Q1
# 2               None  ...               None                 CUP DISPENSER
# 3  00045-571-601-835  ...               None                COMPUTER TOWER
# 4          CD5294G9T  ...               None                          None
# 5        VS812847203  ...               None                          None
# 6       E4MSCX012824  ...                YES           ASUS CHROMEBOX CN60
#
#   Manufacturer_reference Model Number_reference Serial Number_reference  \
# 0                   ASUS         CHROMEBOX CN60            E4MSCX011443
# 1               CRES COR    C0151FPWUA12B2083Q1         EAJ-J203747-044
# 2                 HOBART               CTC2X2-5                    None
# 3                   DELL           OPTIPLEX 280       00045-571-601-835
# 4                   None                   None                    None
# 5                   None                   None                    None
# 6                   ASUS         CHROMEBOX CN60            E4MSCX012824
#
#   Cost Center_reference COST_reference Date Acquired_reference  \
# 0      High School West         1100.0                    None
# 1         Middle School         1458.0              2009-08-01
# 2     Elementary School          385.0              2004-07-23
# 3     Elementary School          693.0              2011-02-22
# 4                  None            NaN                    None
# 5                  None            NaN                    None
# 6      High School East         2300.0                    None
#
#   Funding Code_reference PO Number_reference
# 0                   6001                None
# 1                   5101             FF-2234
# 2                   5101              510307
# 3                      0                None
# 4                   None                None
# 5                   None                None
# 6                   6001             24-1234
#
# [7 rows x 28 columns]

# %%
# Clean up the column names to drop `_scan`
diffs_df.rename(columns={col: col.replace('_scan', '') for col in diffs_df.columns}, inplace=True)

# Remove the key column as it is no longer needed
diffs_df.drop('key', axis=1, inplace=True)

# Remove the reference columns as they are no longer needed
diffs_df.drop([col for col in diffs_df.columns if col.endswith('_reference')], axis=1, inplace=True)
diffs_df
# Out:
#   Status Barcode Number   Source   Room Federal?  \
# 0      C          11944   TipWeb    223      YES
# 1      C           8010   TipWeb  LOBBY     None
# 2      F           2330  NextGen   CAFE     None
# 3      C           3715  NextGen    602     None
# 4      N          11762     None    107      YES
# 5      N          12667     None    208     None
# 6      M          11965   TipWeb    210      YES
#
#                     Description Manufacturer         Model Number  \
# 0           ASUS CHROMEBOX CN60         ASUS       CHROMEBOX CN60
# 1  CRES COR C0151FPWUA12B2083Q1     CRES COR  C0151FPWUA12B2083Q1
# 2                 CUP DISPENSER       HOBART             CTC2X2-5
# 3                COMPUTER TOWER           HP                 360X
# 4                        Laptop       lenovo                 100e
# 5                    Smartboard    Viewsonic             VS 15057
# 6           ASUS CHROMEBOX CN60         ASUS       CHROMEBOX CN60
#
#        Serial Number        Cost Center    COST Date Acquired Funding Code  \
# 0       E4MSCX011443   High School West  1100.0          None         6001
# 1    EAJ-J203747-044   High School West  1458.0    2009-08-01         5101
# 2               None  Elementary School   385.0    2004-07-23         5101
# 3  00045-571-601-835  Elementary School   693.0    2011-02-22            0
# 4          CD5294G9T      Middle School     NaN          None         None
# 5        VS812847203  Elementary School     NaN          None         None
# 6       E4MSCX012824   High School East  2300.0          None         6001
#
#   PO Number
# 0   23-5432
# 1   FF-2234
# 2    510307
# 3      None
# 4      None
# 5      None
# 6   24-1234
